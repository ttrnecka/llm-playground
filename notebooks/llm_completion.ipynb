# %% [markdown]
# ## Loading a Key

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    print("OPENAI_API_KEY is not set")
elif not api_key.startswith("sk-proj-"):
    print("OPENAI_API_KEY is not a valid OpenAI API key")
else:
    print("OPENAI_API_KEY is set")
# Out:
# OPENAI_API_KEY is set

# %% [markdown]
# Prepare payload

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [{"role": "user", "content": "Tell me a fun fact."}],
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact.'}]}

# %% [markdown]
# Call endpoint

# %%
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'chatcmpl-DbTLNcgNpWbvDmK45uH0O4kZh6A77',
#  'object': 'chat.completion',
#  'created': 1777823305,
#  'model': 'gpt-5-nano-2025-08-07',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Wombat poop is cube-shaped, not round—this helps prevent it from rolling away and helps wombats mark their territory.',
#     'refusal': None,
#     'annotations': []},
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 12,
#   'completion_tokens': 419,
#   'total_tokens': 431,
#   'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#   'completion_tokens_details': {'reasoning_tokens': 384,
#    'audio_tokens': 0,
#    'accepted_prediction_tokens': 0,
#    'rejected_prediction_tokens': 0}},
#  'service_tier': 'default',
#  'system_fingerprint': None}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Wombat poop is cube-shaped, not round—this helps prevent it from rolling away and helps wombats mark their territory.'

# %%
from openai import OpenAI

openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])  

response.choices[0].message.content
# Out:
# 'Fun fact: Bananas are technically berries, but strawberries aren’t. Botanically, a berry comes from a single ovary and contains multiple seeds, which fits bananas, while strawberries are aggregates of many tiny ovaries from one flower.'
